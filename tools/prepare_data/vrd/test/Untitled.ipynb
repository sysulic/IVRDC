# %%
import cPickle as cp

# f = open('test_gt_file.pkl',"rb")
# dic = cp.load(f)
# all_gts = dic['gt_label']
# print all_gts[0]

# %%
# all_gt_bboxes = dic['gt_box']
# print all_gt_bboxes

# %%
# f = open('test_gt_objects.pkl',"rb")
# dic = cp.load(f)
# all_gts = dic['gt_obj']
# print all_gts

# %%
# all_bboxes = dic['gt_bbox']
# print all_bboxes
# Out:
# [[[275, 192, 568, 885], [342, 292, 569, 529], [395, 433, 423, 475], [356, 465, 566, 592], [6, 421, 744, 1019], [274, 10, 747, 440], [3, 285, 300, 436]], [[369, 108, 686, 682], [383, 260, 697, 626], [556, 507, 1022, 680]], [[1, 4, 309, 423], [108, 393, 232, 503], [275, 471, 303, 507], [1, 297, 216, 617], [46, 437, 195, 483]], [[198, 173, 362, 266], [68, 326, 625, 966], [221, 257, 337, 292], [68, 326, 625, 966]], [[1, 148, 287, 430], [1, 184, 797, 499], [371, 304, 433, 359], [1, 463, 442, 598], [2, 147, 286, 443], [45, 293, 238, 382]], [[67, 546, 417, 748], [2, 667, 419, 1023], [2, 1, 764, 452]], [[334, 240, 411, 472], [335, 278, 413, 398], [353, 389, 401, 464], [196, 498, 261, 527], [494, 350, 623, 526]], [[63, 500, 428, 676], [62, 97, 563, 938], [2, 644, 680, 1021], [527, 808, 598, 923]], [[17, 146, 368, 681], [181, 320, 752, 681], [36, 255, 248, 588], [123, 201, 180, 228], [287, 238, 352, 377], [320, 368, 360, 483], [103, 175, 179, 267]], [[280, 566, 387, 1001], [137, 466, 367, 647]
# ...

# %%
import json
f = open('test_image_paths.json')
test_img_paths = json.load(f)
len_=len(test_img_paths)
print test_img_paths
# Out:
# [u'../dataset/vrd/images/test/3845770407_1a8cd41230_b.jpg', u'../dataset/vrd/images/test/6279585054_1f9d450f35_b.jpg', u'../dataset/vrd/images/test/2584263186_3969c8a53e_b.jpg', u'../dataset/vrd/images/test/4418514401_cd86bc8e53_b.jpg', u'../dataset/vrd/images/test/8329270_d36f3afdc8_o.jpg', u'../dataset/vrd/images/test/4150090398_6a7d30fb0a_b.jpg', u'../dataset/vrd/images/test/3825256896_c2d83ba5b9_b.jpg', u'../dataset/vrd/images/test/174196276_8a9cc595cf_b.jpg', u'../dataset/vrd/images/test/9488063880_8321ea21a8_b.jpg', u'../dataset/vrd/images/test/9263069366_e7dc652ed7_b.jpg', u'../dataset/vrd/images/test/5064573447_7da6b6f30f_b.jpg', u'../dataset/vrd/images/test/5219053386_16a6151347_b.jpg', u'../dataset/vrd/images/test/4370372957_91f0753201_b.jpg', u'../dataset/vrd/images/test/4537473706_65cf5e785b_o.jpg', u'../dataset/vrd/images/test/8040139417_ab193b1953_b.jpg', u'../dataset/vrd/images/test/7417695040_ef9d321658_b.jpg', u'../dataset/vrd/images/test/5465443054_1def817670_b.jpg'
# ...

# %%
a = [[0,0,1],[1,20,2]]
if ([0,0,1]) in a:
    print "yes"
# Out:
# yes
